# %%
#Sentiment Analysis on Demonetization in India using Apache Spark SQL
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
demonetization_tweets=spark.read.format("csv").option("header", "true").load("/FileStore/tables/demonetization_tweets.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
demonetization_tweets.show()
demonetization_tweets.registerTempTable("tweets")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------------------+---------+-------------------+-------------------+-------------------+------------------+------------------+--------------------+--------------------+--------------------+---------------+------------+---------+---------+
#                  _c0|                   X|                text|favorited|      favoriteCount|          replyToSN|            created|         truncated|        replyToSID|                  id|          replyToUID|        statusSource|     screenName|retweetCount|isRetweet|retweeted|
# +--------------------+--------------------+--------------------+---------+-------------------+-------------------+-------------------+------------------+------------------+--------------------+--------------------+--------------------+---------------+------------+---------+---------+
#                    1|                   1|RT @rssurjewala: ...|    FALSE|                  0|                 NA|2016-11-23 18:40:30|             FALSE|                NA|  801495656976318464|                  NA|&#34;&lt;a href=&#34;&#34;http:/...|HASHTAGFARZIWAL|         331|     TRUE|    FALSE|
#                    2|                   2|RT @Hemant_80: Di...|    FALSE|                  0|                 NA|2016-11-23 18:40:29|             FALSE|                NA|  801495654778413056|                  NA|&#34;&lt;a href=&#34;&#34;http:/...| PRAMODKAUSHIK9|          66|     TRUE|    FALSE|
#                    3|                   3|RT @roshankar: Fo...|     null|               null|               null|               null|              null|              null|                null|                null|                null|           null|        null|     null|     null|
# If not for Aam Aadmi|      listen to th�&#34;|               FALSE|        0|                 NA|2016-11-23 18:40:03|              FALSE|                NA|801495544266821632|                  NA|&#34;&lt;a href=&#34;&#34;http:/...|     rahulja13034944|             12|        TRUE|    FALSE|     null|
#                    4|                   4|RT @ANI_news: Gur...|    FALSE|                  0|                 NA|2016-11-23 18:39:59|             FALSE|                NA|  801495527024160768|                  NA|&#34;&lt;a href=&#34;&#34;http:/...|      deeptiyvd|         338|     TRUE|    FALSE|
#                    5|                   5|RT @satishacharya...|    FALSE|                  0|                 NA|2016-11-23 18:39:39|             FALSE|                NA|  801495445583360000|                  NA|&#34;&lt;a href=&#34;&#34;http:/...|      CPIMBadli|         120|     TRUE|    FALSE|
#                    6|                   6|@DerekScissors1: ...|    FALSE|                  0|     DerekScissors1|2016-11-23 18:39:11|             FALSE|                NA|  801495326439964672|          2586266100|&#34;&lt;a href=&#34;&#34;http:/...|    ambazaarmag|           0|    FALSE|    FALSE|
#                    7|                   7|RT @gauravcsawant...|    FALSE|                  0|                 NA|2016-11-23 18:38:53|             FALSE|                NA|  801495248710967296|                  NA|&#34;&lt;a href=&#34;&#34;http:/...|        bhodia1|         637|     TRUE|    FALSE|
#                    8|                   8|RT @Joydeep_911: ...|     null|               null|               null|               null|              null|              null|                null|                null|                null|           null|        null|     null|     null|
# Walk for #Corrupt...|               FALSE|                   0|       NA|2016-11-23 18:38:20|              FALSE|                 NA|801495113092497408|                NA|&#34;&lt;a href=&#34;&#34;http:/...|     KARUNASHANKEROJ|                 112|           TRUE|       FALSE|     null|     null|
#                    9|                   9|RT @sumitbhati200...|     null|               null|               null|               null|              null|              null|                null|                null|                null|           null|        null|     null|     null|
# And respect their...|but support oppos...|               FALSE|        0|                 NA|2016-11-23 18:38:09|              FALSE|                NA|801495064270794752|                  NA|&#34;&lt;a href=&#34;&#34;http:/...|      sumitbhati2002|              1|        TRUE|    FALSE|     null|
#                   10|                  10|National reform n...|    FALSE|                  0|                 NA|2016-11-23 18:38:00|              TRUE|                NA|  801495027645939712|                  NA|&#34;&lt;a href=&#34;&#34;https:...|  HelpIndia2016|           0|    FALSE|    FALSE|
#                   11|                  11|Many opposition l...|     null|               null|               null|               null|              null|              null|                null|                null|                null|           null|        null|     null|     null|
# And respect their...|but support oppos...|               FALSE|        1|                 NA|2016-11-23 18:37:47|              FALSE|                NA|801494974844043264|                  NA|&#34;&lt;a href=&#34;&#34;http:/...|      sumitbhati2002|              1|       FALSE|    FALSE|     null|
#                   12|                  12|RT @Joydas: Quest...|    FALSE|                  0|                 NA|2016-11-23 18:37:25|             FALSE|                NA|  801494883068317696|                  NA|&#34;&lt;a href=&#34;&#34;http:/...|   MonishGavand|         120|     TRUE|    FALSE|
#                   13|                  13|@Jaggesh2 Bharat ...|    FALSE|                  0|           Jaggesh2|2016-11-23 18:37:15|             FALSE|801482081511448576|  801494840018108416|          1225924610|&#34;&lt;a href=&#34;&#34;http:/...|  yuvaraj_karki|           0|    FALSE|    FALSE|
#                   14|                  14|RT @Atheist_Krish...|     null|               null|               null|               null|              null|              null|                null|                null|                null|           null|        null|     null|     null|
# . https://t.co/A8...|               FALSE|                   0|       NA|2016-11-23 18:36:39|              FALSE|                 NA|801494687345324032|                NA|&#34;&lt;a href=&#34;&#34;http:/...|             PMKejri|                  45|           TRUE|       FALSE|     null|     null|
#                   15|                  15|RT @sona2905: Whe...|    FALSE|                  0|                 NA|2016-11-23 18:36:37|             FALSE|                NA|  801494679258677248|                  NA|&#34;&lt;a href=&#34;&#34;http:/...|      hkgupta16|          50|     TRUE|    FALSE|
# +--------------------+--------------------+--------------------+---------+-------------------+-------------------+-------------------+------------------+------------------+--------------------+--------------------+--------------------+---------------+------------+---------+---------+
# only showing top 20 rows
#
# </div>

# %%
#Calculating retweet count at each time stamp
retweet_sum=spark.sql("select sum(retweetCount) as RetweetCount,created from tweets group by created")
retweet_sum.show()
display(retweet_sum)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+-------------------+
# RetweetCount|            created|
# +------------+-------------------+
#        954.0|2016-11-23 16:12:48|
#          0.0|2016-11-23 15:57:38|
#         19.0|2016-11-23 15:43:30|
#        637.0|2016-11-23 14:38:21|
#         10.0|2016-11-23 14:28:21|
#          0.0|2016-11-23 13:15:59|
#        637.0|2016-11-23 12:59:22|
#        176.0|2016-11-23 09:57:12|
#        637.0|2016-11-23 09:39:56|
#        637.0|2016-11-23 08:24:06|
#         14.0|2016-11-23 04:05:44|
#        132.0|2016-11-23 03:39:04|
#        123.0|2016-11-23 01:45:56|
#          0.0|2016-11-22 17:19:16|
#          0.0|2016-11-22 15:23:40|
#          0.0|2016-11-22 15:05:10|
#        331.0|2016-11-22 14:51:55|
#         44.0|2016-11-22 14:16:19|
#          0.0|2016-11-22 14:09:23|
#        331.0|2016-11-22 12:39:39|
# +------------+-------------------+
# only showing top 20 rows
#
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
r><td>null</td><td>shenoy70</td></tr><tr><td>0.0</td><td>Win the Customer</td></tr><tr><td>null</td><td>vsangur2</td></tr><tr><td>null</td><td>3198991</td></tr><tr><td>null</td><td>mayfair_housing</td></tr><tr><td>null</td><td>ibhagwa_n</td></tr><tr><td>null</td><td>laxmisagarnitw</td></tr><tr><td>null</td><td>chikryazhovp</td></tr><tr><td>null</td><td>43</td></tr><tr><td>null</td><td>5</td></tr><tr><td>null</td><td>ManiKing_0179</td></tr><tr><td>null</td><td>lakshman_POMA</td></tr><tr><td>null</td><td>mspalv76</td></tr><tr><td>1.0</td><td>Pluggio</td></tr><tr><td>null</td><td>MaverickLG</td></tr><tr><td>null</td><td>newsanti</td></tr><tr><td>null</td>< ...

# %%
# Getting Reaction of People on Demonetization
reaction=spark.sql('''select CASE WHEN text like '%Respect%' THEN "POSITIVE"
                   WHEN text like '%symptom%' THEN "POSITIVE"
 WHEN text like '%terrorists%' THEN "POSITIVE"\
 WHEN text like '%National%' THEN "POSITIVE"
 WHEN text like '%reform%' THEN"POSITIVE"
 WHEN text like '%support%' THEN "POSITIVE"
 WHEN text like '%#CorruptionFreeIndia%' THEN "POSITIVE"
 WHEN text like '%respect%' THEN "POSITIVE"
 WHEN text like '%Gandhi%' THEN "POSITIVE"
 WHEN text like '%vote%' THEN "POSITIVE"
 WHEN text like '%fishy%' THEN "NEGATIVE"
 WHEN text like '%disclosure%' THEN "NEGATIVE"
WHEN text like '%Reddy Wedding%' THEN "NEGATIVE"
WHEN text like '%protesting%' THEN "NEGATIVE"
WHEN text like '%hards%' THEN "NEGATIVE"
WHEN text like '%Kerala%' THEN "NEGATIVE"
WHEN text like '%hurt%' THEN "NEGATIVE"
WHEN text like '%USELESS%' THEN "NEGATIVE"
WHEN text like '%Disaster!%' THEN "NEGATIVE"
WHEN text like '%Black%' THEN "NEGATIVE"
WHEN text like '%negative%' THEN "NEGATIVE"
WHEN text like '%impact%' THEN "NEGATIVE"
WHEN text like '%opposing%' THEN "NEGATIVE"
ELSE "NEUTRAL"
     END AS Reaction
from tweets''')

reaction.show()

reaction.registerTempTable("reaction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+
# Reaction|
# +--------+
# NEGATIVE|
# POSITIVE|
#  NEUTRAL|
#  NEUTRAL|
#  NEUTRAL|
# NEGATIVE|
# POSITIVE|
# POSITIVE|
# POSITIVE|
#  NEUTRAL|
#  NEUTRAL|
#  NEUTRAL|
# POSITIVE|
#  NEUTRAL|
#  NEUTRAL|
# POSITIVE|
# NEGATIVE|
#  NEUTRAL|
#  NEUTRAL|
#  NEUTRAL|
# +--------+
# only showing top 20 rows
#
# </div>

# %%
reaction_count=spark.sql("select reaction, count(reaction) from reaction group by reaction")
display(reaction_count)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>reaction</th><th>count(reaction)</th></tr></thead><tbody><tr><td>POSITIVE</td><td>2196</td></tr><tr><td>NEGATIVE</td><td>1198</td></tr><tr><td>NEUTRAL</td><td>17957</td></tr></tbody></table></div>
